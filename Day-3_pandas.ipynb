# %%
import pandas as pd

# %%
#pd.Series(col,Index)#note:Series(S capital)
a=["sitara","appu","sam","triveni"]
r=pd.Series(a,index=[1,2,3,4])
print(r)
# Out:
# 1     sitara
# 2       appu
# 3        sam
# 4    triveni
# dtype: object

# %%
a=["sitara","appu","sam","triveni"]
i=[1,2,3,4]
r=pd.Series(a,i)
print(r)
# Out:
# 1     sitara
# 2       appu
# 3        sam
# 4    triveni
# dtype: object

# %%
#loading csv file
dia=pd.read_csv("/content/csv.file.csv")
dia
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-afef28952116> in <cell line: 2>()
#       1 #loading csv file
# ----> 2 dia=pd.read_csv("/content/csv.file.csv")
#       3 dia
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
demo=pd.read_csv("/content/demodt.csv.txt",sep=",")
demo

# %%
diaxl=pd.read_excel("/content/diabetes.xl.csv.xlsx")
diaxl

# %%
#to load xl sheet
diaxls=pd.read_excel("/content/diabetes.xl.csv.xlsx",sheet_name=(1))
diaxls

# %%
#describing a dataframe
diaxl.describe()

# %%
#difference of pd files
a=pd.read_csv("/content/demodt.csv.txt")
print(demo.shape)
print(demo.shape[0])
print(demo.shape[1])

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
df

# %%
print(df.isnull())

# %%
print(df.isnull().sum())

# %%
df.dropna()

# %%
df

# %%
df1=pd.read_csv("/content/grades_withnulls.csv")
df1.dropna(inplace=True)
df1

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mdf=df.dropna()
mdf

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555)

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555,inplace=True)
df2

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mv=df1["SEM1"].mean()
print(mv)
df2.fillna(mv,inplace=True)
df2

# %%
mydf=pd.read_csv("/content/grades_withnulls.csv")
mv=mydf["SEM1"].mean()
print(mv)
mydf.fillna(mv,inplace=True)
mydf

# %%
#access the data
#iloc=integer location,index
#loc=field names,index
#dfname.loc[index]--->rows
#dfname.loc[st:stop]--->range of rows
#dfname.iloc[r_ind,col_ind]--->rows&col
mydf.loc[0]#first record,record mean it gives rows

# %%
#accessing using index function
print(mydf[mydf.index==7])
print("accessing specific row & column")
print(mydf.loc[mydf.index==7,"Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed  Average
# 7  Mari        N   7.7   8.0   7.1     B       1      7.6
# accessing specific row & column
# 7    B
# Name: Grade, dtype: object

# %%
mydf.loc[5:7,"SEM1"]
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
mydf.iloc[10:12,0:2]#both rows and col--index
# Out:
#     Names Initials
# 10  Kiran        V
# 11   Maya        N

# %%
mydf[mydf.Grade=="A"]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed   Average
# 1   Rajesh        M  8.900000   9.1   9.3     A       1  9.100000
# 2   Kissan        V  9.900000   9.8  10.0     A       0  9.900000
# 5      Raj        M  8.900000   9.1   9.3     A       1  9.100000
# 6   Hassan        V  9.900000   9.0   9.2     A       1  9.366667
# 9   Rajini        M  8.992857   9.1   9.3     A       0  9.130952
# 10   Kiran        V  8.992857   9.3   9.2     A       0  9.164286
# 13  Rajesh        M  8.900000   9.1   9.3     A       1  9.100000
# 14    Riya        M  9.300000   9.9  10.0     A       1  9.733333
# 15    Sana        V  9.900000   9.3   9.2     A       0  9.466667

# %%
mydf[mydf.SEM2==9.1]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed   Average
# 1   Rajesh        M  8.900000   9.1   9.3     A       1  9.100000
# 4     Jeen        K  9.800000   9.1   9.9    A+       1  9.600000
# 5      Raj        M  8.900000   9.1   9.3     A       1  9.100000
# 8     Jess        K  8.992857   9.1   9.9    A+       1  9.330952
# 9   Rajini        M  8.992857   9.1   9.3     A       0  9.130952
# 12   Jolin        K  9.800000   9.1   9.9    A+       1  9.600000
# 13  Rajesh        M  8.900000   9.1   9.3     A       1  9.100000

# %%
#print only the records whose scored 9.3 in SEM3.
mydf[mydf.SEM3==9.3]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed   Average
# 1   Rajesh        M  8.900000   9.1   9.3     A       1  9.100000
# 5      Raj        M  8.900000   9.1   9.3     A       1  9.100000
# 9   Rajini        M  8.992857   9.1   9.3     A       0  9.130952
# 13  Rajesh        M  8.900000   9.1   9.3     A       1  9.100000

# %%
mydf.loc[mydf.SEM1>9.8,"Names"]
# Out:
# 2     Kissan
# 6     Hassan
# 15      Sana
# Name: Names, dtype: object

# %%
#access the grades of students who scored more than 9.7 in sem3
mydf.loc[mydf.SEM3>9.7,"Grade"]
#accessing the records with sem>9.7 but printing only Grade coloumn
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
mydf.drop_duplicates(inplace=True)#viewing and saving=inplace=True
mydf
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed   Average
# 0      Joe        K  9.800000  10.0   9.900000    A+       1  9.900000
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1  9.100000
# 2   Kissan        V  9.900000   9.8  10.000000     A       0  9.900000
# 3     Mary        N  7.700000   8.0   8.992857     B       0  8.230952
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1  9.600000
# 5      Raj        M  8.900000   9.1   9.300000     A       1  9.100000
# 6   Hassan        V  9.900000   9.0   9.200000     A       1  9.366667
# 7     Mari        N  7.700000   8.0   7.100000     B       1  7.600000
# 8     Jess        K  8.992857   9.1   9.900000    A+       1  9.330952
# 9   Rajini        M  8.992857   9.1   9.300000     A       0  9.130952
# 10   Kiran        V  8.992857   9.3   9.200000     A       0  9.164286
# 11    Maya        N  7.700000   8.0   7.100000     B       0  7.600000
# ...

# %%
mydf.head()#by default val 5 you can also specify using values.
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed   Average
# 0     Joe        K   9.8  10.0   9.900000    A+       1  9.900000
# 1  Rajesh        M   8.9   9.1   9.300000     A       1  9.100000
# 2  Kissan        V   9.9   9.8  10.000000     A       0  9.900000
# 3    Mary        N   7.7   8.0   8.992857     B       0  8.230952
# 4    Jeen        K   9.8   9.1   9.900000    A+       1  9.600000

# %%
mydf.tail()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   Average
# 12   Jolin        K   9.8   9.1   9.9    A+       1  9.600000
# 13  Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# 14    Riya        M   9.3   9.9  10.0     A       1  9.733333
# 15    Sana        V   9.9   9.3   9.2     A       0  9.466667
# 16    Mark        N   7.7   8.0   7.0     B       0  7.566667

# %%
#columns!
colnames=mydf.columns #view coloumn names
print(colnames)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed',
#        'Average'],
#       dtype='object')

# %%
#columns!
collist=list(mydf.columns) #view coloumn names
print(collist)

# %%
#Rename the col
mydf.rename(columns={"Grade":"GPA"},inplace=True)
mydf.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed', 'Average',
#        'conduct'],
#       dtype='object')

# %%
#creating a newcolumn
#dfname['new col']=values
mydf["conduct"]="Good"
mydf
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed   Average conduct
# 0      Joe        K  9.800000  10.0   9.900000    A+       1  9.900000    Good
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1  9.100000    Good
# 2   Kissan        V  9.900000   9.8  10.000000     A       0  9.900000    Good
# 3     Mary        N  7.700000   8.0   8.992857     B       0  8.230952    Good
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1  9.600000    Good
# 5      Raj        M  8.900000   9.1   9.300000     A       1  9.100000    Good
# 6   Hassan        V  9.900000   9.0   9.200000     A       1  9.366667    Good
# 7     Mari        N  7.700000   8.0   7.100000     B       1  7.600000    Good
# 8     Jess        K  8.992857   9.1   9.900000    A+       1  9.330952    Good
# 9   Rajini        M  8.992857   9.1   9.300000     A       0  9.130952    Good
# 10   Kiran        V  8.992857   9.3   9.200000     A       0  9.164286    Good
# ...

# %%
#create a new col called avg with avg values of SEM1,SEM2,SEM3

mydf["Average"]=(mydf["SEM1"]+mydf["SEM2"]+mydf["SEM3"])/3
mydf
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed   Average
# 0      Joe        K  9.800000  10.0   9.900000    A+       1  9.900000
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1  9.100000
# 2   Kissan        V  9.900000   9.8  10.000000     A       0  9.900000
# 3     Mary        N  7.700000   8.0   8.992857     B       0  8.230952
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1  9.600000
# 5      Raj        M  8.900000   9.1   9.300000     A       1  9.100000
# 6   Hassan        V  9.900000   9.0   9.200000     A       1  9.366667
# 7     Mari        N  7.700000   8.0   7.100000     B       1  7.600000
# 8     Jess        K  8.992857   9.1   9.900000    A+       1  9.330952
# 9   Rajini        M  8.992857   9.1   9.300000     A       0  9.130952
# 10   Kiran        V  8.992857   9.3   9.200000     A       0  9.164286
# 11    Maya        N  7.700000   8.0   7.100000     B       0  7.600000
# ...

# %%
mydf=pd.read_csv("/content/grades_withnulls.csv")
mv=mydf["SEM1"].mean()
print(mv)
mydf.fillna(mv,inplace=True)
mydf
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %% [markdown]
# DATA VISUALISATION WITH PANDAS

# %%
#plotting with pandas
import pandas as pd
mydf['SEM1'].plot.line() #dfname.plot.line()
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line()#plotting multiple cols
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot.line(subplots=True)#all numeric col are plotted!
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot(kind="scatter",y="Names",x="Average")
# Out:
# <Axes: xlabel='Average', ylabel='Names'>

# %%
mydf.plot(kind="hist",x="Names",y="Average")#,x axis is count,y should be numeric
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydf
# Out:
#      Names Initials      SEM1  SEM2       SEM3 GPA  Placed   Average conduct
# 0      Joe        K  9.800000  10.0   9.900000  A+       1  9.900000    Good
# 1   Rajesh        M  8.900000   9.1   9.300000   A       1  9.100000    Good
# 2   Kissan        V  9.900000   9.8  10.000000   A       0  9.900000    Good
# 3     Mary        N  7.700000   8.0   8.992857   B       0  8.230952    Good
# 4     Jeen        K  9.800000   9.1   9.900000  A+       1  9.600000    Good
# 5      Raj        M  8.900000   9.1   9.300000   A       1  9.100000    Good
# 6   Hassan        V  9.900000   9.0   9.200000   A       1  9.366667    Good
# 7     Mari        N  7.700000   8.0   7.100000   B       1  7.600000    Good
# 8     Jess        K  8.992857   9.1   9.900000  A+       1  9.330952    Good
# 9   Rajini        M  8.992857   9.1   9.300000   A       0  9.130952    Good
# 10   Kiran        V  8.992857   9.3   9.200000   A       0  9.164286    Good
# ...

# %%
mydf.to_csv("mydf.csv")
