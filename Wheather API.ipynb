# %%
import requests
api_key="8ee54b232a0c4320b9253646242802"
city=input("Enter a city name")
url=f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response=requests.get(url)
data=response.json()

if response ==200:


print(data['error']['message'])
if data['error']['code']==1006:
   print("No location found")
else:
    print("city",data['location']['name'])
    print("state",data['location']['region'])
    print("country",data['location']['country'])
    print("temperature",data['current']['temp_c'])
    print("wind direction",data['current']['wind_dir'])
    print("wind speed"),data['current']['wind_mph']
    print("humidity"),data['current']['humidity']
    print("feels like"),data['current']['feelslike_c']
# Out:
# Enter a city nametfuik
# No matching location found.
# No location found

# %%
type (data)
# Out:
# dict

# %%
print("city",data['location']['name'])
print("state",data['location']['region'])
print("country",data['location']['country'])
print("temperature",data['current']['temp_c'])
print("wind direction",data['current']['wind_dir'])
print("wind speed"),data['current']['wind_mph']
print("humidity"),data['current']['humidity']
print("feels like"),data['current']['feelslike_c']
# Out:
# city Vizag
# state Andhra Pradesh
# country India
# temperature 28.2
# wind direction SE
# wind speed
# humidity
# feels like
# (None, 29.7)

# %%
import requests
api_key='a7e47878b23a4ff3a3d53832242802'
city=input("enter city")
url=f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
code=response
response=requests.get(url)
data=response.json()
if response.status_code == 200:
  #printing!
  print("city",data['location']['name'])
  print("state",data['location']['region'])
  print("country",data['location']['country'])
  print("temperature",data['current']['temp_c'])
  print("wind direction",data['current']['wind_dir'])
  print("wind speed"),data['current']['wind_mph']
  print("humidity"),data['current']['humidity']
  print("feels like"),data['current']['feelslike_c']
else:
  print(data['error']['message'])
# Out:
# enter cityguntur
# city Guntur
# state Andhra Pradesh
# country India
# temperature 31.0
# wind direction E
# wind speed
# humidity
# feels like

# %%
import requests

url = "https://stylinandy-taxee.p.rapidapi.com/v2/federal/%7Byear%7D"

headers = {
	"Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJBUElfS0VZX01BTkFHRVIiLCJodHRwOi8vdGF4ZWUuaW8vdXNlcl9pZCI6IjU3Y2IyMWE2YmI4N2MxMDA0NGE2NmE2MiIsImh0dHA6Ly90YXhlZS5pby9zY29wZXMiOlsiYXBpIl0sImlhdCI6MTQ3MzAxODA1OX0.xkn1_LHnLijhYMONl5iXhKD1vsdm0_5AtSKGsPrVtxI",
	"X-RapidAPI-Key": "86f07015d0msh06c3a8598574b7fp16b995jsne099650ab9e8",
	"X-RapidAPI-Host": "stylinandy-taxee.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-a6e492a4e718> in <cell line: 13>()
#      11 response = requests.get(url, headers=headers)
#      12
# ---> 13 print(response.json())
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
const axios = require('axios');

const options = {
  method: 'POST',
  url: 'https://sales-tax-calculator.p.rapidapi.com/rates',
  headers: {
    'content-type': 'application/json',
    'X-RapidAPI-Key': 'abda0da374msh31c763199500085p12783bjsn89e02ed2d036',
    'X-RapidAPI-Host': 'sales-tax-calculator.p.rapidapi.com'
  },
  data: {
    city: 'Menlo Park',
    state: 'CA',
    street: '1 Hacker Way',
    zip: '94025'
  }
};

try {
	const response = await axios.request(options);
	console.log(response.daconst response = await axios.request(options);
	console.log(response.data);
} catch (error) {
	console.error(error);
}
# Out:
#   File "<ipython-input-10-4ecbfeb97643>", line 23
#     } catch (error) {
#     ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '(' on line 21

# %%
import requests

url = "https://sales-tax-calculator.p.rapidapi.com/rates"

payload = {
	"city": "Menlo Park",
	"state": "CA",
	"street": "1 Hacker Way",
	"zip": "94025"
}
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "SIGN-UP-FOR-KEY",
	"X-RapidAPI-Host": "sales-tax-calculator.p.rapidapi.com"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'message': 'You are not subscribed to this API.'}
